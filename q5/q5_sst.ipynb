# %% [markdown]
# # Question 5: Sentiment Analysis with T5
#
# This notebook implements sentiment analysis using a T5-Small model fine-tuned on SST-2.

# %% [markdown]
# ## Part (b): Model Selection
#
# We are using the following model from Hugging Face:
#
# **Model:** `lightsout19/t5-sst2`
# - Model Page: https://huggingface.co/lightsout19/t5-sst2

# %% [markdown]
# ### Install and Import Dependencies

# %%
# !pip install -U transformers torch datasets
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (4.57.3)
# Requirement already satisfied: torch in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (2.8.0)
# Requirement already satisfied: datasets in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (4.4.2)
# Requirement already satisfied: filelock in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from torch) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from torch) (2025.10.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from datasets) (2.3.1)
# Requirement already satisfied: httpx<1.0.0 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from datasets) (0.70.18)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: anyio in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from httpx<1.0.0->datasets) (4.9.0)
# Requirement already satisfied: certifi in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from httpx<1.0.0->datasets) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from httpx<1.0.0->datasets) (3.10)
# Requirement already satisfied: h11>=0.16 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.15.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/talweiss/Library/Python/3.9/lib/python/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
from datasets import load_dataset
from tqdm.auto import tqdm

# %% [markdown]
# ### Load Model and Tokenizer

# %%
# Load the T5-SST2 model and tokenizer
model_name = "lightsout19/t5-sst2"
print(f"Loading model: {model_name}")

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

print("Model loaded successfully!")
print(f"Number of labels: {model.config.num_labels}")
# Out:
# Loading model: lightsout19/t5-sst2
# Model loaded successfully!
# Number of labels: 2

# %% [markdown]
# ### Define Prediction Function

# %%
def predict_sentiment(text):
    """
    Predict sentiment for a given text.
    
    Args:
        text (str): Input text to analyze
        
    Returns:
        dict: Dictionary containing predicted label and confidence scores
    """
    # Tokenize input
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512)
    
    # Get model prediction
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits
        
    # Get probabilities
    probabilities = torch.softmax(logits, dim=-1)[0]
    predicted_class = torch.argmax(probabilities).item()
    
    # Map labels (LABEL_0 = negative, LABEL_1 = positive)
    label_map = {0: "negative", 1: "positive"}
    
    return {
        "text": text,
        "predicted_label": label_map[predicted_class],
        "confidence": probabilities[predicted_class].item(),
        "negative_score": probabilities[0].item(),
        "positive_score": probabilities[1].item()
    }

# %% [markdown]
# ## Part (c): Predict Sentiment for 4 Sentences
#
# Now we'll predict sentiment for the four required sentences.

# %% [markdown]
# ### Sentence 1: "This movie is awesome"

# %%
sentence1 = "This movie is awesome"
result1 = predict_sentiment(sentence1)

print("=" * 60)
print(f"Input: {result1['text']}")
print(f"Predicted Sentiment: {result1['predicted_label'].upper()}")
print(f"Confidence: {result1['confidence']:.4f}")
print(f"\nDetailed Scores:")
print(f"  Negative: {result1['negative_score']:.4f}")
print(f"  Positive: {result1['positive_score']:.4f}")
print("=" * 60)
# Out:
# ============================================================
# Input: This movie is awesome
# Predicted Sentiment: POSITIVE
# Confidence: 0.9992
#
# Detailed Scores:
#   Negative: 0.0008
#   Positive: 0.9992
# ============================================================

# %% [markdown]
# ### Sentence 2: "I didn't like the movie so much"

# %%
sentence2 = "I didn't like the movie so much"
result2 = predict_sentiment(sentence2)

print("=" * 60)
print(f"Input: {result2['text']}")
print(f"Predicted Sentiment: {result2['predicted_label'].upper()}")
print(f"Confidence: {result2['confidence']:.4f}")
print(f"\nDetailed Scores:")
print(f"  Negative: {result2['negative_score']:.4f}")
print(f"  Positive: {result2['positive_score']:.4f}")
print("=" * 60)
# Out:
# ============================================================
# Input: I didn't like the movie so much
# Predicted Sentiment: NEGATIVE
# Confidence: 0.9897
#
# Detailed Scores:
#   Negative: 0.9897
#   Positive: 0.0103
# ============================================================

# %% [markdown]
# ### Sentence 3: "I'm not sure what I think about this movie."

# %%
sentence3 = "I'm not sure what I think about this movie."
result3 = predict_sentiment(sentence3)

print("=" * 60)
print(f"Input: {result3['text']}")
print(f"Predicted Sentiment: {result3['predicted_label'].upper()}")
print(f"Confidence: {result3['confidence']:.4f}")
print(f"\nDetailed Scores:")
print(f"  Negative: {result3['negative_score']:.4f}")
print(f"  Positive: {result3['positive_score']:.4f}")
print("=" * 60)
# Out:
# ============================================================
# Input: I'm not sure what I think about this movie.
# Predicted Sentiment: NEGATIVE
# Confidence: 0.9766
#
# Detailed Scores:
#   Negative: 0.9766
#   Positive: 0.0234
# ============================================================

# %% [markdown]
# ### Sentence 4: "Did you like the movie?"

# %%
sentence4 = "Did you like the movie?"
result4 = predict_sentiment(sentence4)

print("=" * 60)
print(f"Input: {result4['text']}")
print(f"Predicted Sentiment: {result4['predicted_label'].upper()}")
print(f"Confidence: {result4['confidence']:.4f}")
print(f"\nDetailed Scores:")
print(f"  Negative: {result4['negative_score']:.4f}")
print(f"  Positive: {result4['positive_score']:.4f}")
print("=" * 60)
# Out:
# ============================================================
# Input: Did you like the movie?
# Predicted Sentiment: POSITIVE
# Confidence: 0.9577
#
# Detailed Scores:
#   Negative: 0.0423
#   Positive: 0.9577
# ============================================================

# %% [markdown]
# ### Summary of All Predictions

# %%
# Create summary table
print("\n" + "=" * 80)
print("SUMMARY OF SENTIMENT PREDICTIONS")
print("=" * 80)
print(f"{'Sentence':<50} {'Prediction':<12} {'Confidence':>10}")
print("-" * 80)

for i, result in enumerate([result1, result2, result3, result4], 1):
    text = result['text'][:47] + "..." if len(result['text']) > 50 else result['text']
    print(f"{text:<50} {result['predicted_label']:<12} {result['confidence']:>10.4f}")

print("=" * 80)
# Out:
# ================================================================================
# SUMMARY OF SENTIMENT PREDICTIONS
# ================================================================================
# Sentence                                           Prediction   Confidence
# --------------------------------------------------------------------------------
# This movie is awesome                              positive         0.9992
# I didn't like the movie so much                    negative         0.9897
# I'm not sure what I think about this movie.        negative         0.9766
# Did you like the movie?                            positive         0.9577
# ================================================================================

# %% [markdown]
# ## Part (d): Evaluate Model on SST-2 Dataset
#
# Now we'll load the full SST-2 dataset and evaluate the model's accuracy on the validation set.

# %% [markdown]
# ### Load SST-2 Dataset

# %%
# Load SST-2 dataset from Stanford NLP
print("Loading SST-2 dataset...")
dataset = load_dataset("stanfordnlp/sst2")

print("\nDataset structure:")
print(dataset)

# Get validation set
validation_set = dataset['validation']
print(f"\nValidation set size: {len(validation_set)} examples")
# Out:
# Loading SST-2 dataset...
#
# Dataset structure:
# DatasetDict({
#     train: Dataset({
#         features: ['idx', 'sentence', 'label'],
#         num_rows: 67349
#     })
#     validation: Dataset({
#         features: ['idx', 'sentence', 'label'],
#         num_rows: 872
#     })
#     test: Dataset({
#         features: ['idx', 'sentence', 'label'],
#         num_rows: 1821
#     })
# })
#
# Validation set size: 872 examples

# %% [markdown]
# ### Define Evaluation Function

# %%
def evaluate_on_sst2(model, tokenizer, dataset, batch_size=32):
    """
    Evaluate the model on the SST-2 dataset.
    
    Args:
        model: The classification model
        tokenizer: The tokenizer
        dataset: The dataset split to evaluate on
        batch_size: Batch size for processing
        
    Returns:
        dict: Dictionary containing accuracy and detailed results
    """
    model.eval()
    correct = 0
    total = 0
    
    print(f"Evaluating on {len(dataset)} examples...")
    
    # Process in batches for efficiency
    for i in tqdm(range(0, len(dataset), batch_size)):
        batch = dataset[i:min(i + batch_size, len(dataset))]
        texts = batch['sentence']
        labels = batch['label']
        
        # Tokenize batch
        inputs = tokenizer(texts, return_tensors="pt", truncation=True, 
                          max_length=512, padding=True)
        
        # Get predictions
        with torch.no_grad():
            outputs = model(**inputs)
            logits = outputs.logits
            predictions = torch.argmax(logits, dim=-1)
        
        # Count correct predictions
        for pred, true_label in zip(predictions.tolist(), labels):
            if pred == true_label:
                correct += 1
            total += 1
    
    accuracy = correct / total
    
    return {
        "accuracy": accuracy,
        "correct": correct,
        "total": total
    }

# %% [markdown]
# ### Run Evaluation

# %%
# Evaluate on validation set
results = evaluate_on_sst2(model, tokenizer, validation_set, batch_size=32)

print("\n" + "=" * 70)
print("EVALUATION RESULTS ON SST-2 VALIDATION SET")
print("=" * 70)
print(f"Total Examples:    {results['total']}")
print(f"Correct:           {results['correct']}")
print(f"Incorrect:         {results['total'] - results['correct']}")
print(f"\n✓ Accuracy:        {results['accuracy']:.4f} ({results['accuracy']*100:.2f}%)")
print("=" * 70)

# Report for written solution
print(f"Accuracy: {results['accuracy']*100:.2f}%")
# Out:
# Evaluating on 872 examples...
#   0%|          | 0/28 [00:00<?, ?it/s]
# ======================================================================
# EVALUATION RESULTS ON SST-2 VALIDATION SET
# ======================================================================
# Total Examples:    872
# Correct:           786
# Incorrect:         86
#
# ✓ Accuracy:        0.9014 (90.14%)
# ======================================================================
# Accuracy: 90.14%

# %% [markdown]
# ### Analysis: Check Dataset Balance

# %%
# Check class distribution in validation set
labels = validation_set['label']
negative_count = sum(1 for label in labels if label == 0)
positive_count = sum(1 for label in labels if label == 1)

print("\n" + "=" * 70)
print("CLASS DISTRIBUTION IN SST-2 VALIDATION SET")
print("=" * 70)
print(f"Negative examples: {negative_count} ({negative_count/len(labels)*100:.1f}%)")
print(f"Positive examples: {positive_count} ({positive_count/len(labels)*100:.1f}%)")
print(f"\nTotal examples:    {len(labels)}")
print(f"Balance ratio:     {min(negative_count, positive_count)/max(negative_count, positive_count):.3f}")
print("=" * 70)
# Out:
# ======================================================================
# CLASS DISTRIBUTION IN SST-2 VALIDATION SET
# ======================================================================
# Negative examples: 428 (49.1%)
# Positive examples: 444 (50.9%)
#
# Total examples:    872
# Balance ratio:     0.964
# ======================================================================
